# %% [markdown]
# # Neural networks
# In this notebook, we explore 2 different neural network architectures that succeeded in predicting sales volumes for a kaggle competition.

# %% [markdown]
# ## Notebook settings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from scipy.stats import describe
import seaborn as sns
from pylab import rcParams

pd.options.display.max_columns = 12
pd.options.display.max_rows = 24

# disable warnings in Anaconda
warnings.simplefilter('ignore')

# plots inisde jupyter notebook
# %matplotlib inline

sns.set(style='darkgrid', palette='muted')
color_scheme = {
    'red': '#F1637A',
    'green': '#6ABB3E',
    'blue': '#3D8DEA',
    'black': '#000000'
}

# use svg for all plots within inline backend
# %config InlineBackend.figure_format = 'svg'

# increase default plot size
rcParams['figure.figsize'] = 8, 6

# %% [markdown]
# ## Loading data
# In order for this to work, download all datasets from kaggle competition:
# https://www.kaggle.com/c/demand-forecasting-kernels-only
# and place them in `../data/` folder.
# We could not append datasets to our repo because of copyrights.

# %%
df_train = pd.read_csv('../data/train.csv')
df_test = pd.read_csv('../data/test.csv')

# %% [markdown]
# Before we do anything, we want to have both sets in a format with 500 sales columns and 1 row for each day.

# %%
df_train.index = pd.to_datetime(df_train['date'])
df_train.drop('date', axis=1, inplace=True)
df_test.index = pd.to_datetime(df_test['date'])
df_test.drop('date', axis=1, inplace=True)

# %%
df_train.head()
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14
# 2013-01-04      1     1     13
# 2013-01-05      1     1     10

# %%
from itertools import product, starmap


def storeitems():
    return product(range(1,51), range(1,11))


def storeitems_column_names():
    return list(starmap(lambda i,s: f'item_{i}_store_{s}_sales', storeitems()))


def sales_by_storeitem(df):
    ret = pd.DataFrame(index=df.index.unique())
    for i, s in storeitems():
        ret[f'item_{i}_store_{s}_sales'] = df[(df['item'] == i) & (df['store'] == s)]['sales'].values
    return ret

# %%
df_train = sales_by_storeitem(df_train)
# for test set, we just fill y values with zeros (they won't be used anyway)
df_test['sales'] = np.zeros(df_test.shape[0])
df_test = sales_by_storeitem(df_test)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2013-01-01 to 2017-12-31
# Columns: 500 entries, item_1_store_1_sales to item_50_store_10_sales
# dtypes: int64(500)
# memory usage: 7.0 MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90 entries, 2018-01-01 to 2018-03-31
# Columns: 500 entries, item_1_store_1_sales to item_50_store_10_sales
# dtypes: float64(500)
# memory usage: 352.3 KB

# %% [markdown]
# We combine data to prepare it for the model, and later split back into train and test set, not to repeat same transformations twice.

# %%
# make sure all column names are the same and in the same order
col_names = list(zip(df_test.columns, df_train.columns))
for cn in col_names:
    assert cn[0] == cn[1]

# %%
df_test['is_test'] = np.repeat(True, df_test.shape[0])
df_train['is_test'] = np.repeat(False, df_train.shape[0])
df_total = pd.concat([df_train, df_test])
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1916 entries, 2013-01-01 to 2018-03-31
# Columns: 501 entries, item_1_store_1_sales to is_test
# dtypes: bool(1), float64(500)
# memory usage: 7.3 MB

# %% [markdown]
# ### Features
# One-hot encoding day of week and month of year to make sure the networks recognize the seasonality in the data.

# %%
weekday_df = pd.get_dummies(df_total.index.weekday, prefix='weekday')
weekday_df.index = df_total.index

# %%
month_df = pd.get_dummies(df_total.index.month, prefix='month')
month_df.index =  df_total.index

# %%
df_total = pd.concat([weekday_df, month_df, df_total], axis=1)

# %%
assert df_total.isna().any().any() == False

# %% [markdown]
# We also want to append sales from previous day to each row, which we will then use as input data.

# %%
def shift_series(series, days):
    return series.transform(lambda x: x.shift(days))


def shift_series_in_df(df, series_names=[], days_delta=90):
    ret = pd.DataFrame(index=df.index.copy())
    str_sgn = 'future' if np.sign(days_delta) < 0 else 'past'
    for sn in series_names:
        ret[f'{sn}_{str_sgn}_{np.abs(days_delta)}'] = shift_series(df[sn], days_delta)
    return ret

    
def stack_shifted_sales(df, days_deltas=[1, 90, 360]):
    names = storeitems_column_names()
    dfs = [df.copy()]
    for delta in days_deltas:
        shifted = shift_series_in_df(df, series_names=names, days_delta=delta)
        dfs.append(shifted)
    return pd.concat(dfs, axis=1, sort=False, copy=False)

# %%
df_total = stack_shifted_sales(df_total, days_deltas=[1])
df_total.dropna(inplace=True)

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1915 entries, 2013-01-02 to 2018-03-31
# Freq: D
# Columns: 1020 entries, weekday_0 to item_50_store_10_sales_past_1
# dtypes: bool(1), float64(1000), uint8(19)
# memory usage: 14.7 MB

# %% [markdown]
# We need to make sure that stacked and not-stacked sales columns appar in the same order. We do this by sorting the names (as strings), which works fine because we only need 1 past day for the network (see regression models and their rolling mechanism if you are interested in rolling more than 1 past days of sales as input).

# %%
sales_cols = [col for col in df_total.columns if '_sales' in col and '_sales_' not in col]
stacked_sales_cols = [col for col in df_total.columns if '_sales_' in col]
other_cols = [col for col in df_total.columns if col not in set(sales_cols) and col not in set(stacked_sales_cols)]

sales_cols = sorted(sales_cols)
stacked_sales_cols = sorted(stacked_sales_cols)

new_cols = other_cols + stacked_sales_cols + sales_cols

# %%
df_total = df_total.reindex(columns=new_cols)

# %%
assert df_total.isna().any().any() == False

# %% [markdown]
# ### Scaling
# With combined datasets and shifted sales, we can now correctly min-max scale all data.
# This is necessary for neural networks to work as intended.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
scaler = MinMaxScaler(feature_range=(0,1))
cols_to_scale = [col for col in df_total.columns if 'weekday' not in col and 'month' not in col]
scaled_cols = scaler.fit_transform(df_total[cols_to_scale])
df_total[cols_to_scale] = scaled_cols

# %% [markdown]
# ### Split back to train and test set

# %%
df_train = df_total[df_total['is_test'] == False].drop('is_test', axis=1)
df_test = df_total[df_total['is_test'] == True].drop('is_test', axis=1)

# %% [markdown]
# ## Training models
# First, we need to separate training data into input and target vectors, and separate part of training data as validation data for our models.

# %%
X_cols_stacked = [col for col in df_train.columns if '_past_' in col]
X_cols_caldata = [col for col in df_train.columns if 'weekday_' in col or 'month_' in col or 'year' in col]
X_cols = X_cols_stacked + X_cols_caldata

X = df_train[X_cols]

# %%
X_colset = set(X_cols)
y_cols = [col for col in df_train.columns if col not in X_colset]

y = df_train[y_cols]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1825 entries, 2013-01-02 to 2017-12-31
# Freq: D
# Columns: 519 entries, item_10_store_10_sales_past_1 to month_12
# dtypes: float64(500), uint8(19)
# memory usage: 7.0 MB

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1825 entries, 2013-01-02 to 2017-12-31
# Freq: D
# Columns: 500 entries, item_10_store_10_sales to item_9_store_9_sales
# dtypes: float64(500)
# memory usage: 7.0 MB

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# To achieve similar error values as on Kaggle, we will use only 1st quarter of 2017 for validation (test set contains 1st quarter of 2018 and the data is highly seasonal).

# %%
X_valid, y_valid = X_valid.head(90), y_valid.head(90)

# %% [markdown]
# For Keras, we need to make further transformations on input values:

# %%
X_train_vals = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_valid_vals = X_valid.values.reshape((X_valid.shape[0], 1, X_valid.shape[1]))

# %% [markdown]
# ### Defining models

# %%
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Conv1D, Input, Dropout, AvgPool1D, Reshape, Concatenate
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Simple LSTM model:

# %%
basic_model = Sequential()
basic_model.add(LSTM(500, input_shape=(X_train_vals.shape[1], X_train_vals.shape[2])))
basic_model.add(Dense(500))
basic_model.compile(loss='mean_absolute_error', optimizer='adam')

# %% [markdown]
# More complex model combining LSTM with convolutional layers:

# %%
inputs = Input(shape=(X_train_vals.shape[1], X_train_vals.shape[2]))
# top pipeline
top_lstm = LSTM(500)(inputs)
top_dense = Dense(500, activation='relu')(top_lstm)
top_dropout = Dropout(500)(top_dense)
# bottom pipeline
bottom_dense = Dense(500)(inputs)
bottom_conv1 = Conv1D(
    500, 
    kernel_size=1,
    input_shape=(X_train_vals.shape[1], X_train_vals.shape[2])
)(bottom_dense)
bottom_conv2 = Conv1D(
    1000,
    kernel_size=50,
    padding='same',
    activation='relu'
)(bottom_conv1)
bottom_conv3 = Conv1D(
    500,
    kernel_size=10,
    padding='same',
    activation='relu'
)(bottom_conv2)
bottom_pooling = AvgPool1D(
    pool_size=60, 
    padding='same'
)(bottom_conv3)
bottom_reshape = Reshape(
    target_shape=[500]
)(bottom_conv3)
# concat output from both pipelines
final_concat = Concatenate()([top_dropout, bottom_reshape])
final_dense = Dense(500)(final_concat)
# compile and return
complex_model = Model(inputs=inputs, outputs=final_dense)
complex_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mape'])

# %% [markdown]
# Now we can fit the models:

# %%
basic_history = basic_model.fit(
    X_train_vals, 
    y_train.values, 
    epochs=60, 
    batch_size=30,
    validation_data=(X_valid_vals, y_valid.values),
    verbose=2,
    shuffle=False
)
# Out:
# Train on 1460 samples, validate on 90 samples
# Epoch 1/60
#  - 3s - loss: 0.1490 - val_loss: 0.0936
# Epoch 2/60
#  - 0s - loss: 0.0933 - val_loss: 0.0737
# Epoch 3/60
#  - 0s - loss: 0.0838 - val_loss: 0.0688
# Epoch 4/60
#  - 0s - loss: 0.0731 - val_loss: 0.0622
# Epoch 5/60
#  - 0s - loss: 0.0712 - val_loss: 0.0602
# Epoch 6/60
#  - 0s - loss: 0.0781 - val_loss: 0.0610
# Epoch 7/60
#  - 0s - loss: 0.0762 - val_loss: 0.0722
# Epoch 8/60
#  - 0s - loss: 0.0967 - val_loss: 0.0994
# Epoch 9/60
#  - 0s - loss: 0.0840 - val_loss: 0.0767
# Epoch 10/60
#  - 0s - loss: 0.0806 - val_loss: 0.0728
# Epoch 11/60
#  - 0s - loss: 0.0735 - val_loss: 0.0611
# Epoch 12/60
#  - 0s - loss: 0.0706 - val_loss: 0.0720
# Epoch 13/60
#  - 0s - loss: 0.0745 - val_loss: 0.0586
# Epoch 14/60
#  - 0s - loss: 0.0630 - val_loss: 0.0574
# Epoch 15/60
#  - 0s - loss: 0.0651 - val_loss: 0.0627
# Epoch 16/60
#  - 0s - loss: 0.0678 - val_loss: 0.0572
# Epoch 17/60
#  - 0s - loss: 0.0631 - val_loss: 0.0654
# Epoch 18/60
#  - 0s - loss: 0.0688 - val_loss: 0.0588
# Epoch 19/60
#  - 0s - loss: 0.0611 - val_loss: 0.0566
# Epoch 20/60
#  - 0s - loss: 0.0630 - val_loss: 0.0560
# Epoch 21/60
#  - 0s - loss: 0.0607 - val_loss: 0.0587
# Epoch 22/60
#  - 0s - loss: 0.0638 - val_loss: 0.0655
# Epoch 23/60
#  - 0s - loss: 0.0657 - val_loss: 0.0581
# Epoch 24/60
#  - 0s - loss: 0.0588 - val_loss: 0.0560
# Epoch 25/60
#  - 0s - loss: 0.0627 - val_loss: 0.0566
# Epoch 26/60
#  - 0s - loss: 0.0637 - val_loss: 0.0562
# Epoch 27/60
#  - 0s - loss: 0.0615 - val_loss: 0.0646
# Epoch 28/60
#  - 0s - loss: 0.0728 - val_loss: 0.0561
# Epoch 29/60
#  - 0s - loss: 0.0624 - val_loss: 0.0560
# Epoch 30/60
#  - 0s - loss: 0.0626 - val_loss: 0.0582
# Epoch 31/60
#  - 0s - loss: 0.0637 - val_loss: 0.0625
# Epoch 32/60
#  - 0s - loss: 0.0631 - val_loss: 0.0564
# Epoch 33/60
#  - 0s - loss: 0.0592 - val_loss: 0.0558
# Epoch 34/60
#  - 0s - loss: 0.0603 - val_loss: 0.0562
# Epoch 35/60
#  - 0s - loss: 0.0599 - val_loss: 0.0602
# Epoch 36/60
#  - 0s - loss: 0.0653 - val_loss: 0.0603
# Epoch 37/60
#  - 0s - loss: 0.0633 - val_loss: 0.0565
# Epoch 38/60
#  - 0s - loss: 0.0639 - val_loss: 0.0558
# Epoch 39/60
#  - 0s - loss: 0.0606 - val_loss: 0.0581
# Epoch 40/60
#  - 0s - loss: 0.0650 - val_loss: 0.0617
# Epoch 41/60
#  - 0s - loss: 0.0646 - val_loss: 0.0565
# Epoch 42/60
#  - 0s - loss: 0.0593 - val_loss: 0.0569
# Epoch 43/60
#  - 0s - loss: 0.0596 - val_loss: 0.0597
# Epoch 44/60
#  - 0s - loss: 0.0621 - val_loss: 0.0592
# Epoch 45/60
#  - 0s - loss: 0.0606 - val_loss: 0.0564
# Epoch 46/60
#  - 0s - loss: 0.0642 - val_loss: 0.0561
# Epoch 47/60
#  - 0s - loss: 0.0624 - val_loss: 0.0559
# Epoch 48/60
#  - 0s - loss: 0.0635 - val_loss: 0.0641
# Epoch 49/60
#  - 0s - loss: 0.0688 - val_loss: 0.0570
# Epoch 50/60
#  - 0s - loss: 0.0601 - val_loss: 0.0564
# Epoch 51/60
#  - 0s - loss: 0.0601 - val_loss: 0.0583
# Epoch 52/60
#  - 0s - loss: 0.0604 - val_loss: 0.0575
# Epoch 53/60
#  - 0s - loss: 0.0593 - val_loss: 0.0558
# Epoch 54/60
#  - 0s - loss: 0.0598 - val_loss: 0.0571
# Epoch 55/60
#  - 0s - loss: 0.0599 - val_loss: 0.0584
# Epoch 56/60
#  - 0s - loss: 0.0594 - val_loss: 0.0562
# Epoch 57/60
#  - 0s - loss: 0.0590 - val_loss: 0.0562
# Epoch 58/60
#  - 0s - loss: 0.0598 - val_loss: 0.0585
# Epoch 59/60
#  - 0s - loss: 0.0604 - val_loss: 0.0585
# Epoch 60/60
#  - 0s - loss: 0.0597 - val_loss: 0.0559

# %%
def plot_history(history):
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
plot_history(basic_history)

# %%
complex_history = complex_model.fit(
    X_train_vals, 
    y_train.values, 
    epochs=130, 
    batch_size=70,
    validation_data=(X_valid_vals, y_valid.values),
    verbose=2,
    shuffle=False
)
# Out:
# Train on 1460 samples, validate on 90 samples
# Epoch 1/130
#  - 9s - loss: 0.0526 - mean_absolute_percentage_error: 373.2478 - val_loss: 0.0154 - val_mean_absolute_percentage_error: 27.4651
# Epoch 2/130
#  - 4s - loss: 0.0130 - mean_absolute_percentage_error: 385.6123 - val_loss: 0.0090 - val_mean_absolute_percentage_error: 20.1775
# Epoch 3/130
#  - 4s - loss: 0.0097 - mean_absolute_percentage_error: 328.9703 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 19.0265
# Epoch 4/130
#  - 4s - loss: 0.0093 - mean_absolute_percentage_error: 334.3246 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 19.1308
# Epoch 5/130
#  - 4s - loss: 0.0094 - mean_absolute_percentage_error: 379.5606 - val_loss: 0.0099 - val_mean_absolute_percentage_error: 22.7420
# Epoch 6/130
#  - 4s - loss: 0.0091 - mean_absolute_percentage_error: 284.1339 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 16.1743
# Epoch 7/130
#  - 4s - loss: 0.0071 - mean_absolute_percentage_error: 320.8680 - val_loss: 0.0064 - val_mean_absolute_percentage_error: 17.2474
# Epoch 8/130
#  - 4s - loss: 0.0086 - mean_absolute_percentage_error: 292.9875 - val_loss: 0.0071 - val_mean_absolute_percentage_error: 18.8306
# Epoch 9/130
#  - 4s - loss: 0.0078 - mean_absolute_percentage_error: 306.3646 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 14.2057
# Epoch 10/130
#  - 4s - loss: 0.0067 - mean_absolute_percentage_error: 310.2341 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 14.4766
# Epoch 11/130
#  - 4s - loss: 0.0071 - mean_absolute_percentage_error: 294.3096 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 14.7548
# Epoch 12/130
#  - 4s - loss: 0.0071 - mean_absolute_percentage_error: 293.9500 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.1089
# Epoch 13/130
#  - 5s - loss: 0.0066 - mean_absolute_percentage_error: 303.5029 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.0114
# Epoch 14/130
#  - 4s - loss: 0.0066 - mean_absolute_percentage_error: 300.6256 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.0645
# Epoch 15/130
#  - 4s - loss: 0.0066 - mean_absolute_percentage_error: 297.0371 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.0042
# Epoch 16/130
#  - 4s - loss: 0.0066 - mean_absolute_percentage_error: 299.3282 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9578
# Epoch 17/130
#  - 4s - loss: 0.0065 - mean_absolute_percentage_error: 300.0947 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9336
# Epoch 18/130
#  - 4s - loss: 0.0065 - mean_absolute_percentage_error: 299.7799 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9000
# Epoch 19/130
#  - 4s - loss: 0.0065 - mean_absolute_percentage_error: 299.7743 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8832
# Epoch 20/130
#  - 4s - loss: 0.0064 - mean_absolute_percentage_error: 301.1976 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.8823
# Epoch 21/130
#  - 4s - loss: 0.0063 - mean_absolute_percentage_error: 300.2129 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9100
# Epoch 22/130
#  - 4s - loss: 0.0064 - mean_absolute_percentage_error: 298.1478 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.8926
# Epoch 23/130
#  - 4s - loss: 0.0063 - mean_absolute_percentage_error: 299.3445 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8592
# Epoch 24/130
#  - 4s - loss: 0.0063 - mean_absolute_percentage_error: 300.8234 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8585
# Epoch 25/130
#  - 4s - loss: 0.0063 - mean_absolute_percentage_error: 303.5006 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8539
# Epoch 26/130
#  - 4s - loss: 0.0062 - mean_absolute_percentage_error: 302.2995 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.8735
# Epoch 27/130
#  - 4s - loss: 0.0063 - mean_absolute_percentage_error: 301.0220 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8362
# Epoch 28/130
#  - 4s - loss: 0.0063 - mean_absolute_percentage_error: 303.4104 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8442
# Epoch 29/130
#  - 4s - loss: 0.0062 - mean_absolute_percentage_error: 307.1336 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8278
# Epoch 30/130
#  - 4s - loss: 0.0062 - mean_absolute_percentage_error: 305.3540 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8437
# Epoch 31/130
#  - 4s - loss: 0.0062 - mean_absolute_percentage_error: 307.2273 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8257
# Epoch 32/130
#  - 4s - loss: 0.0062 - mean_absolute_percentage_error: 305.4058 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8436
# Epoch 33/130
#  - 4s - loss: 0.0061 - mean_absolute_percentage_error: 306.5805 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9231
# Epoch 34/130
#  - 4s - loss: 0.0064 - mean_absolute_percentage_error: 304.9844 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.8800
# Epoch 35/130
#  - 4s - loss: 0.0064 - mean_absolute_percentage_error: 305.1460 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8656
# Epoch 36/130
#  - 4s - loss: 0.0063 - mean_absolute_percentage_error: 310.1146 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.8428
# Epoch 37/130
#  - 4s - loss: 0.0061 - mean_absolute_percentage_error: 312.5845 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8445
# Epoch 38/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 312.3965 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8318
# Epoch 39/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 312.2682 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8300
# Epoch 40/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 311.4566 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8421
# Epoch 41/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 311.4869 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8299
# Epoch 42/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 316.3097 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8352
# Epoch 43/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 313.7610 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8255
# Epoch 44/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 318.7393 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8412
# Epoch 45/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 312.4173 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8179
# Epoch 46/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 319.9003 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8534
# Epoch 47/130
#  - 4s - loss: 0.0061 - mean_absolute_percentage_error: 308.8115 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8232
# Epoch 48/130
#  - 4s - loss: 0.0061 - mean_absolute_percentage_error: 311.2604 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8838
# Epoch 49/130
#  - 4s - loss: 0.0061 - mean_absolute_percentage_error: 306.8282 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8137
# Epoch 50/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 321.3207 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8596
# Epoch 51/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 320.0197 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8383
# Epoch 52/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 326.0700 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8455
# Epoch 53/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 322.2178 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8562
# Epoch 54/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 326.5531 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8446
# Epoch 55/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 321.7411 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8820
# Epoch 56/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 322.5496 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8325
# Epoch 57/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 333.7077 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8762
# Epoch 58/130
#  - 5s - loss: 0.0060 - mean_absolute_percentage_error: 316.3768 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8557
# Epoch 59/130
#  - 5s - loss: 0.0060 - mean_absolute_percentage_error: 326.7968 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8786
# Epoch 60/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 306.8471 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.8496
# Epoch 61/130
#  - 4s - loss: 0.0061 - mean_absolute_percentage_error: 322.3396 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8878
# Epoch 62/130
#  - 5s - loss: 0.0061 - mean_absolute_percentage_error: 313.2535 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8635
# Epoch 63/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 326.8353 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8670
# Epoch 64/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 320.2606 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8161
# Epoch 65/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 322.9395 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8741
# Epoch 66/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 324.6359 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8742
# Epoch 67/130
#  - 5s - loss: 0.0059 - mean_absolute_percentage_error: 325.9265 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8543
# Epoch 68/130
#  - 5s - loss: 0.0059 - mean_absolute_percentage_error: 328.4835 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8942
# Epoch 69/130
#  - 5s - loss: 0.0059 - mean_absolute_percentage_error: 329.2345 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8669
# Epoch 70/130
#  - 5s - loss: 0.0059 - mean_absolute_percentage_error: 327.4787 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.9164
# Epoch 71/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 328.6439 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8661
# Epoch 72/130
#  - 5s - loss: 0.0059 - mean_absolute_percentage_error: 336.4532 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8816
# Epoch 73/130
#  - 5s - loss: 0.0060 - mean_absolute_percentage_error: 318.0515 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8628
# Epoch 74/130
#  - 5s - loss: 0.0061 - mean_absolute_percentage_error: 323.9458 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8762
# Epoch 75/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 326.6580 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 13.9571
# Epoch 76/130
#  - 5s - loss: 0.0059 - mean_absolute_percentage_error: 314.6238 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.8734
# Epoch 77/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 305.6153 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9590
# Epoch 78/130
#  - 5s - loss: 0.0058 - mean_absolute_percentage_error: 317.2670 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9937
# Epoch 79/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 316.8392 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8244
# Epoch 80/130
#  - 4s - loss: 0.0064 - mean_absolute_percentage_error: 304.4884 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 13.9341
# Epoch 81/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 322.9916 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8587
# Epoch 82/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 324.0080 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8503
# Epoch 83/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 323.2606 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8669
# Epoch 84/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 326.7040 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8453
# Epoch 85/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 320.4232 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8885
# Epoch 86/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 320.4411 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8803
# Epoch 87/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 312.3908 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8641
# Epoch 88/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 326.9196 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 13.8990
# Epoch 89/130
#  - 4s - loss: 0.0059 - mean_absolute_percentage_error: 326.2220 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8836
# Epoch 90/130
#  - 5s - loss: 0.0060 - mean_absolute_percentage_error: 328.6828 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8949
# Epoch 91/130
#  - 5s - loss: 0.0060 - mean_absolute_percentage_error: 328.2566 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.8988
# Epoch 92/130
#  - 4s - loss: 0.0061 - mean_absolute_percentage_error: 321.4515 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 13.9010
# Epoch 93/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 323.5150 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8949
# Epoch 94/130
#  - 4s - loss: 0.0061 - mean_absolute_percentage_error: 329.6963 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 13.8808
# Epoch 95/130
#  - 4s - loss: 0.0060 - mean_absolute_percentage_error: 332.3740 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.0428
# Epoch 96/130
#  - 4s - loss: 0.0062 - mean_absolute_percentage_error: 313.0900 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 14.3400
# Epoch 97/130
#  - 4s - loss: 0.0067 - mean_absolute_percentage_error: 318.4138 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 14.0122
# Epoch 98/130
#  - 4s - loss: 0.0062 - mean_absolute_percentage_error: 311.6950 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9577
# Epoch 99/130
#  - 4s - loss: 0.0064 - mean_absolute_percentage_error: 301.0971 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.8808
# Epoch 100/130
#  - 5s - loss: 0.0063 - mean_absolute_percentage_error: 312.5287 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 13.9750
# Epoch 101/130
#  - 4s - loss: 0.0066 - mean_absolute_percentage_error: 303.5789 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 14.0842
# Epoch 102/130
#  - 5s - loss: 0.0069 - mean_absolute_percentage_error: 307.8886 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.4866
# Epoch 103/130
#  - 4s - loss: 0.0075 - mean_absolute_percentage_error: 304.9211 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 15.7317
# Epoch 104/130
#  - 4s - loss: 0.0092 - mean_absolute_percentage_error: 296.5070 - val_loss: 0.0092 - val_mean_absolute_percentage_error: 21.5837
# Epoch 105/130
#  - 4s - loss: 0.0142 - mean_absolute_percentage_error: 277.2067 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 34.6245
# Epoch 106/130
#  - 4s - loss: 0.0212 - mean_absolute_percentage_error: 258.1962 - val_loss: 0.0096 - val_mean_absolute_percentage_error: 22.7190
# Epoch 107/130
#  - 4s - loss: 0.0101 - mean_absolute_percentage_error: 360.3384 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 19.1075
# Epoch 108/130
#  - 4s - loss: 0.0076 - mean_absolute_percentage_error: 292.0520 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 19.7608
# Epoch 109/130
#  - 4s - loss: 0.0135 - mean_absolute_percentage_error: 282.2437 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 20.2984
# Epoch 110/130
#  - 5s - loss: 0.0107 - mean_absolute_percentage_error: 316.2982 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 15.7243
# Epoch 111/130
#  - 4s - loss: 0.0083 - mean_absolute_percentage_error: 319.4908 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 19.4831
# Epoch 112/130
#  - 4s - loss: 0.0116 - mean_absolute_percentage_error: 293.2391 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 14.9463
# Epoch 113/130
#  - 5s - loss: 0.0078 - mean_absolute_percentage_error: 356.7711 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.1954
# Epoch 114/130
#  - 5s - loss: 0.0075 - mean_absolute_percentage_error: 285.5639 - val_loss: 0.0063 - val_mean_absolute_percentage_error: 17.2265
# Epoch 115/130
#  - 4s - loss: 0.0100 - mean_absolute_percentage_error: 318.4218 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 14.5468
# Epoch 116/130
#  - 4s - loss: 0.0071 - mean_absolute_percentage_error: 346.6663 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.4241
# Epoch 117/130
#  - 5s - loss: 0.0078 - mean_absolute_percentage_error: 312.1521 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 15.2268
# Epoch 118/130
#  - 5s - loss: 0.0082 - mean_absolute_percentage_error: 337.5867 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.2938
# Epoch 119/130
#  - 5s - loss: 0.0072 - mean_absolute_percentage_error: 334.9080 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.3533
# Epoch 120/130
#  - 5s - loss: 0.0075 - mean_absolute_percentage_error: 326.4918 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.2918
# Epoch 121/130
#  - 4s - loss: 0.0073 - mean_absolute_percentage_error: 332.3474 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.1343
# Epoch 122/130
#  - 4s - loss: 0.0072 - mean_absolute_percentage_error: 329.8398 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.1511
# Epoch 123/130
#  - 4s - loss: 0.0072 - mean_absolute_percentage_error: 329.3344 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.0904
# Epoch 124/130
#  - 4s - loss: 0.0071 - mean_absolute_percentage_error: 329.6803 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.0680
# Epoch 125/130
#  - 4s - loss: 0.0071 - mean_absolute_percentage_error: 328.4929 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.0591
# Epoch 126/130
#  - 4s - loss: 0.0070 - mean_absolute_percentage_error: 328.2297 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 14.0314
# Epoch 127/130
#  - 5s - loss: 0.0070 - mean_absolute_percentage_error: 327.6478 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 14.0235
# Epoch 128/130
#  - 4s - loss: 0.0070 - mean_absolute_percentage_error: 328.2278 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 14.0226
# Epoch 129/130
#  - 4s - loss: 0.0070 - mean_absolute_percentage_error: 328.7311 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 14.0066
# Epoch 130/130
#  - 4s - loss: 0.0069 - mean_absolute_percentage_error: 329.0985 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 14.0078

# %%
plot_history(complex_history)

# %% [markdown]
# ## Evaluating model predictions

# %%
def model_eval(model, X_test, y_test):
    """
    Evaluate (step-by-step) model predictions from X_test and return predictions and real values in comparable format.
    """
    # prepare data
    sales_x_cols = [col for col in X_test.columns if 'sales' in col]
    sales_x_idxs = [X_test.columns.get_loc(col) for col in sales_x_cols]
    sales_y_cols = [col for col in y_test.columns if 'sales' in col]
    sales_y_idxs = [y_test.columns.get_loc(col) for col in sales_y_cols]
    n_samples = y_test.shape[0]
    y_pred = np.zeros(y_test.shape)
    # iterate
    x_next = X_test.iloc[0].values
    for i in range(0, n_samples):
        x_arr = np.array([x_next])
        x_arr = x_arr.reshape(x_arr.shape[0], 1, x_arr.shape[1])
        y_pred[i] = model.predict(x_arr)[0] # input for prediction must be 2d, output is immediately extracted from 2d to 1d
        try:
            x_next = X_test.iloc[i+1].values
            x_next[sales_x_idxs] = y_pred[i][sales_y_idxs]
        except IndexError:
            pass  # this happens on last iteration, and x_next does not matter anymore
    return y_pred, y_test.values


def unscale(y_arr, scaler, template_df, toint=False):
    """
    Unscale array y_arr of model predictions, based on a scaler fitted 
    to template_df.
    """
    tmp = template_df.copy()
    tmp[y_cols] = pd.DataFrame(y_arr, index=tmp.index)
    tmp[cols_to_scale] = scaler.inverse_transform(tmp[cols_to_scale])
    if toint:
        return tmp[y_cols].astype(int)
    return tmp[y_cols]


def vector_smape(y_pred, y_real):
    nom = np.abs(y_pred-y_real)
    denom = (np.abs(y_pred) + np.abs(y_real)) / 2
    results = nom / denom
    return 100*np.mean(results)  # in percent, same as at kaggle

# %%
y_pred_basic, y_real = model_eval(basic_model, X_valid, y_valid)

# %%
y_pred_complex = model_eval(complex_model, X_valid, y_valid)[0]

# %%
# this is just for unscaling
template_df = pd.concat([X_valid, y_valid], axis=1)
template_df['is_test'] = np.repeat(True, template_df.shape[0])

# %%
basic_pred = unscale(y_pred_basic, scaler, template_df, toint=True)
complex_pred = unscale(y_pred_complex, scaler, template_df, toint=True)
real = unscale(y_real, scaler, template_df, toint=True)

# %%
basic_smapes = [vector_smape(basic_pred[col], real[col]) for col in basic_pred.columns]
complex_smapes = [vector_smape(complex_pred[col], real[col]) for col in complex_pred.columns]

# %%
sns.distplot(basic_smapes, label='Basic model')
sns.distplot(complex_smapes, label='Complex model')
plt.legend(loc='upper right')
plt.savefig('smape_basic_vs_complex.svg')
plt.show()
# Out:
# /home/kowal/anaconda3/envs/tf/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/kowal/anaconda3/envs/tf/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Depending on training parameters, basic model can sometimes achieve results comparable to the complex one, however after uploading to Kaggle complex model achieved better (and more consistent) results.

# %%
describe(basic_smapes)
# Out:
# DescribeResult(nobs=500, minmax=(8.308005076582367, 32.92032983928369), mean=14.38486309364908, variance=15.226932947067594, skewness=0.9833585640625947, kurtosis=0.9091293473250772)

# %%
describe(complex_smapes)
# Out:
# DescribeResult(nobs=500, minmax=(7.760102886121145, 30.06513477569722), mean=13.610704916515042, variance=14.59374151162919, skewness=0.9759009631552003, kurtosis=0.7808638461204658)

# %% [markdown]
# ### Visualizing model prediction
# We will plot predictions of 2 models for a sample store and item.

# %%
store, item = 1,1
plot_lengths = [7, 30, 90]
rolling_mean_windows = [1, 1, 2]  # to make plots more readable

# %%
storeitem_col = f'item_{item}_store_{store}_sales'

for pl, mw in zip(plot_lengths, rolling_mean_windows):
    plt.plot(basic_pred[storeitem_col].rolling(mw).mean().values[:pl],
             color_scheme['blue'],
             lw=2,
             label='Basic model prediction')
    plt.plot(complex_pred[storeitem_col].rolling(mw).mean().values[:pl],
             color_scheme['green'],
             lw=2, 
             label='Complex model prediction')
    plt.plot(real[storeitem_col].rolling(mw).mean().values[:pl],
             color_scheme['black'],
             lw=2, 
             label='Real values')
    plt.legend(loc='upper left')
    plt.savefig(f'plot_prediction_{pl}_{mw}.svg')
    plt.show()
